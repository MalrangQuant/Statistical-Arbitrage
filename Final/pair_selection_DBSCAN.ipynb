# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import statsmodels.api as sm

from tqdm import tqdm
from hurst import compute_Hc
from sklearn.manifold import TSNE
from sklearn.cluster import DBSCAN
from itertools import combinations
from sklearn.decomposition import PCA
from arch.unitroot import engle_granger
from statsmodels.tsa.stattools import coint
from sklearn.preprocessing import StandardScaler

# %%
price_df = pd.read_csv('./Data/us_etf_price.csv')

# %%
price_df = price_df.astype({'Date': 'datetime64[ns]'})

# %%
price_df['year'] = price_df['Date'].apply(lambda x: x.year)
price_df['month'] = price_df['Date'].apply(lambda x: x.month)

# %%
# formation = price_df[(price_df.year == 2022) & ((price_df.month == 1) | (price_df.month == 2) | (price_df.month == 3))]
# formation = formation.set_index('Date')
# formation_etf_list = list(formation[formation.index == '2022-01-03'].tic.unique())

formation = price_df[(price_df.Date>='2010-01-01') & (price_df.Date<'2011-01-01')]
formation = formation.set_index('Date')
formation_etf_list = list(formation[formation.index == formation.index[0]].tic.unique())

# %%
formation
# Out:
#                  Open       High        Low      Close  Adj Close    Volume  \
# Date
# 2010-01-04  53.470001  53.950001  53.389999  53.860001  40.110847  904100.0
# 2010-01-05  53.930000  54.180000  53.750000  54.150002  40.326817  682300.0
# 2010-01-06  54.119999  54.400002  54.070000  54.279999  40.423626  675600.0
# 2010-01-07  54.270000  54.840000  54.130001  54.750000  40.773643  591800.0
# 2010-01-08  54.680000  54.860001  54.540001  54.849998  40.848118  351400.0
# ...               ...        ...        ...        ...        ...       ...
# 2010-12-27  21.450001  21.540001  21.389999  21.500000  16.015892  101300.0
# 2010-12-28  21.809999  21.809999  21.549999  21.590000  16.082933   49200.0
# 2010-12-29  21.830000  22.070000  21.830000  21.990000  16.380911  162600.0
# 2010-12-30  22.049999  22.100000  21.879999  22.000000  16.388361   55000.0
# 2010-12-31  22.120001  22.340000  22.100000  22.330000  16.634184   70800.0
#
#             tic  year  month
# Date
# 2010-01-04  IVE  2010      1
# 2010-01-05  IVE  2010      1
# 2010-01-06  IVE  2010      1
# 2010-01-07  IVE  2010      1
# 2010-01-08  IVE  2010      1
# ...         ...   ...    ...
# 2010-12-27  EWO  2010     12
# 2010-12-28  EWO  2010     12
# 2010-12-29  EWO  2010     12
# 2010-12-30  EWO  2010     12
# 2010-12-31  EWO  2010     12
#
# [126341 rows x 9 columns]

# %%
len(formation_etf_list)
# Out:
# 456

# %%
close_df = pd.DataFrame(index = formation.index.unique())

for x in tqdm(formation_etf_list):
    tmp = test = formation['Close'][formation.tic == x]
    close_df = pd.concat([close_df, tmp], axis=1)

close_df.columns = formation_etf_list
# Out:
# 100%|██████████| 456/456 [00:02<00:00, 190.36it/s]

# %%
close_df
# Out:
#                   IVE       ERTH     SPXS        RYF       QQXT        RFV  \
# Date
# 2010-01-04  53.860001  25.000000  20325.0  16.326817  17.940001  28.750000
# 2010-01-05  54.150002  25.100000  20137.5  16.312849  17.969999  28.889999
# 2010-01-06  54.279999  25.389999  20050.0  16.592178  18.020000  29.280001
# 2010-01-07  54.750000  25.480000  19800.0  16.871508  18.090000  29.490000
# 2010-01-08  54.849998  25.600000  19587.5  16.752792  18.209999  29.700001
# ...               ...        ...      ...        ...        ...        ...
# 2010-12-27  59.520000  26.370001  11012.5  19.532124  21.020000  34.110001
# 2010-12-28  59.639999  26.240000  11000.0  19.504190  21.090000  34.040001
# 2010-12-29  59.650002  26.510000  10950.0  19.511173  21.219999  34.200001
# 2010-12-30  59.560001  26.370001  10975.0  19.455307  21.219999  34.230000
# 2010-12-31  59.590000  26.400000  10962.5  19.448324  21.100000  34.009998
#
#                   FXN        RWJ    FDD         DOG  ...        DSI  \
# Date                                                 ...
# 2010-01-04  17.350000  26.660000  14.49  206.240005  ...  21.639999
# 2010-01-05  17.650000  26.540001  14.47  206.440002  ...  21.674999
# 2010-01-06  18.010000  26.520000  14.50  206.320007  ...  21.660000
# 2010-01-07  17.930000  26.790001  14.45  205.479996  ...  21.735001
# 2010-01-08  18.170000  26.889999  14.45  205.360001  ...  21.855000
# ...               ...        ...    ...         ...  ...        ...
# 2010-12-27  20.830000  32.959999  13.42  177.800003  ...  23.495001
# 2010-12-28  20.879999  32.930000  13.38  177.360001  ...  23.514999
# 2010-12-29  21.129999  32.919998  13.71  177.240005  ...  23.504999
# 2010-12-30  21.150000  32.840000  13.60  177.559998  ...  23.485001
# 2010-12-31  21.170000  32.490002  13.69  177.320007  ...  23.455000
#
#                   IGE        PJP        IYW       RBLD      FAZ        TOK  \
# Date
# 2010-01-04  35.450001  18.900000  14.622500  39.419998  59008.0  37.480000
# 2010-01-05  35.810001  18.780001  14.600000  39.830002  56704.0  37.520000
# 2010-01-06  36.270000  18.760000  14.497500  40.490002  56352.0  37.650002
# 2010-01-07  36.080002  18.790001  14.442500  40.650002  53184.0  37.639999
# 2010-01-08  36.400002  18.809999  14.552500  41.279999  53792.0  37.770000
# ...               ...        ...        ...        ...      ...        ...
# 2010-12-27  40.880001  23.980000  16.145000  43.799999  30048.0  39.889999
# 2010-12-28  41.180000  23.879999  16.147499  44.020000  29984.0  39.860001
# 2010-12-29  41.560001  23.900000  16.165001  44.610001  30144.0  39.980000
# 2010-12-30  41.599998  23.780001  16.135000  44.549999  30304.0  39.849998
# 2010-12-31  41.689999  23.639999  16.094999  44.709999  30240.0  40.240002
#
#                   XHB        XLE        EWO
# Date
# 2010-01-04  15.320000  58.810001  20.200001
# 2010-01-05  15.430000  59.290001  20.700001
# 2010-01-06  15.510000  60.000000  20.650000
# 2010-01-07  16.150000  59.910000  20.680000
# 2010-01-08  16.219999  60.299999  20.680000
# ...               ...        ...        ...
# 2010-12-27  17.610001  67.169998  21.500000
# 2010-12-28  17.430000  67.419998  21.590000
# 2010-12-29  17.420000  68.089996  21.990000
# 2010-12-30  17.430000  68.150002  22.000000
# 2010-12-31  17.389999  68.250000  22.330000
#
# [252 rows x 456 columns]

# %%
rtn_df = close_df.pct_change()[1:]

# %%
rtn_df_scaled = pd.DataFrame(StandardScaler().fit_transform(rtn_df))

# %%
pca = PCA()
pca.fit(rtn_df_scaled)
cumsum_eigen_value = np.cumsum(pca.explained_variance_ratio_)
pca_components = pca.components_[:np.where(cumsum_eigen_value >= 0.9)[0][0]]

pc_rtn = pd.DataFrame(data=pca_components.T, index=rtn_df.columns)
pc_rtn = pc_rtn.add_prefix("P")
pc_rtn
# Out:
#             P0        P1        P2        P3        P4        P5        P6
# IVE   0.050457 -0.010388 -0.015418  0.015423 -0.087908 -0.012974  0.031737
# ERTH  0.049624  0.012606 -0.006851  0.029204  0.045184 -0.004910 -0.045389
# SPXS -0.051322  0.014020  0.005324 -0.016109  0.039105 -0.021996 -0.025722
# RYF   0.045174 -0.031227 -0.001495 -0.002672 -0.084256 -0.092181 -0.008373
# QQXT  0.047966 -0.040450 -0.018374 -0.034328  0.042957  0.020393  0.011326
# ...        ...       ...       ...       ...       ...       ...       ...
# FAZ  -0.047209  0.017136 -0.015495 -0.082441  0.140960  0.073630 -0.043544
# TOK   0.048614  0.021675 -0.043277 -0.017324  0.004387 -0.001447 -0.048225
# XHB   0.044008 -0.047919  0.042542  0.022880 -0.005663 -0.090182 -0.051286
# XLE   0.047933  0.024726  0.053231 -0.036753 -0.076237  0.103960 -0.068068
# EWO   0.045023  0.069919 -0.070016  0.060495  0.007088 -0.013583 -0.059574
#
# [456 rows x 7 columns]

# %%
data = StandardScaler().fit_transform(pc_rtn)

# %%
clf = DBSCAN(eps=1.8, min_samples=3, n_jobs=1)
clf.fit(data)

labels = clf.labels_
n_clusters_ = len(set(labels)) - (1 if -1 in labels else 0)
print("Clusters discovered: %d" % n_clusters_)
# Out:
# Clusters discovered: 7

# %%
pc_rtn
# Out:
#             P0        P1        P2        P3        P4        P5        P6
# IVE   0.050457 -0.010388 -0.015418  0.015423 -0.087908 -0.012974  0.031737
# ERTH  0.049624  0.012606 -0.006851  0.029204  0.045184 -0.004910 -0.045389
# SPXS -0.051322  0.014020  0.005324 -0.016109  0.039105 -0.021996 -0.025722
# RYF   0.045174 -0.031227 -0.001495 -0.002672 -0.084256 -0.092181 -0.008373
# QQXT  0.047966 -0.040450 -0.018374 -0.034328  0.042957  0.020393  0.011326
# ...        ...       ...       ...       ...       ...       ...       ...
# FAZ  -0.047209  0.017136 -0.015495 -0.082441  0.140960  0.073630 -0.043544
# TOK   0.048614  0.021675 -0.043277 -0.017324  0.004387 -0.001447 -0.048225
# XHB   0.044008 -0.047919  0.042542  0.022880 -0.005663 -0.090182 -0.051286
# XLE   0.047933  0.024726  0.053231 -0.036753 -0.076237  0.103960 -0.068068
# EWO   0.045023  0.069919 -0.070016  0.060495  0.007088 -0.013583 -0.059574
#
# [456 rows x 7 columns]

# %%
clustered = clf.labels_
clustered_series = pd.Series(index = pc_rtn.index, data = clustered.flatten())
clustered_series_all = pd.Series(index = pc_rtn.index, data = clustered.flatten())
clustered_series = clustered_series[clustered_series != 1]

# %%
clustered_series
# Out:
# IVE     0
# ERTH    0
# RYF     0
# QQXT    0
# RFV     0
#        ..
# FAZ     6
# TOK     0
# XHB     0
# XLE     0
# EWO     0
# Length: 440, dtype: int64

# %%
cluster_size_limit = 100
counts = clustered_series.value_counts()
ticker_count_reduced = counts[(counts > 1) & (counts <= cluster_size_limit)]
print("Clusters formed: %d" % len(ticker_count_reduced))
print("Pairs to evaluate: %d" % (ticker_count_reduced*(ticker_count_reduced-1)).sum())
# Out:
# Clusters formed: 6
# Pairs to evaluate: 88

# %%
X_tsne = TSNE(learning_rate = 1000, perplexity = 25, random_state = 1337).fit_transform(pc_rtn)

plt.figure(1, facecolor = 'white', figsize = (15, 10))
plt.clf()
plt.axis('off')

plt.scatter(X_tsne[(labels!=-1), 0], X_tsne[(labels!=-1), 1], s = 100, alpha = 0.85, c = labels[labels!=-1], cmap = cm.Paired)
plt.scatter(X_tsne[(clustered_series_all==-1).values, 0], X_tsne[(clustered_series_all==-1).values, 1], s = 100, alpha = 0.05)
plt.title('T-SNE of all stocks with DBSCAN Clusters Noted')
plt.savefig('T-SNE_plot_for_stock_clusters.png')
plt.show()
# Out:
# /opt/homebrew/Caskroom/miniforge/base/envs/quant/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py:795: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(

# %%
plt.figure(figsize = (12, 7))
plt.barh(range(len(clustered_series.value_counts())), clustered_series.value_counts())
plt.title("Cluster Memeber Counts")
plt.xlabel('Stocks in Cluster')
plt.ylabel("Cluster Member")
plt.savefig('cluster_member_counts.png')
plt.show()

# %%
counts = clustered_series.value_counts()
clusters_viz_list = list(counts[(counts < 500) & (counts > 1)].index)[::-1]
print(clusters_viz_list)
# Out:
# [6, 5, 4, -1, 2, 3, 0]

# %%
for c in clusters_viz_list:
    plt.figure(figsize=(8,6))
    stocks = list(clustered_series[clustered_series==c].index)
    means = np.log(close_df.T.loc[stocks,].T.mean())
    data = np.log(close_df.T.loc[stocks,]).T.sub(means)
    data.plot(title='Stock Time Series for Cluster %d' % c)
    #plt.savefig('stock_price_clsuter_'+str(c)+'.png')
    plt.show()

# %% [markdown]
# # Pair selection

# %%
etf_info = pd.read_csv('./Data/etfs_details_equity.csv')
etf_info['volume'] = etf_info['Avg. Daily Volume'].str.replace(',','').astype('float')
low_volume_etf = etf_info[etf_info.volume < etf_info.volume.quantile(0.1)].Symbol.to_list()

# %%
def Pair_selection(clusters_viz_list, inverse_threshold, coint_pvalue_threshold, hurst_threshold, half_life_threshold, mean_reverting_freq):
    
    selected_pair = []
    for i in tqdm(range(len(clusters_viz_list))):
        test_list = list(clustered_series[clustered_series == clusters_viz_list[i]].index)

        # 1. 거래량 10분위 이하 제거
        vol_screened_test_list = []
        for x in test_list:
            if (x in low_volume_etf) == False:
                vol_screened_test_list.append(x)       
                
        # 2. corr -0.99 보다 작은 etf가 존재하는지 -> 숏포지션 잡을 수 있는지 여부
        short_avail_test_list = []
        for x in vol_screened_test_list:
            if rtn_df.corr()[x].min() < inverse_threshold:
                short_avail_test_list.append(x)
                
        # 3. Cointegration - pvalue 0.05 이하인 pair sorting
        log_price_data = np.log(close_df[short_avail_test_list])
        comb = list(combinations(short_avail_test_list, 2))
        eg_pvalue = {}

        for x in tqdm(comb):
            score, pvalue, _ = coint(log_price_data[x[0]], log_price_data[x[1]], method='aeg')
            eg_pvalue[x] = pvalue

        possible_pair = [x[0] for x in sorted(eg_pvalue.items(), key=lambda item: item[1]) if x[1] <= coint_pvalue_threshold]

        # 4. Hurst exponent test - mean reverting intensity : H < 0.5 이하인 종목 선정
        spread_df = pd.DataFrame(index = log_price_data.index)

        for x in possible_pair:
            spread_df[x] = close_df[x[0]] - close_df[x[1]]
        
        hurst_screened_list = []

        for cnd in possible_pair:
            if compute_Hc(spread_df[cnd])[0] <= hurst_threshold:
                hurst_screened_list.append(cnd)

        spread_df = spread_df[hurst_screened_list]

        # 5. Half life가 trading period 안에 들어오는 종목 스크리닝
        spread_df_lag = spread_df.shift(1)
        spread_df_diff = spread_df - spread_df_lag

        hl_screened_list = []
        for i in range(len(hurst_screened_list)):
            X = sm.add_constant(spread_df_lag.iloc[1:,i])
            model = sm.OLS(spread_df_diff.iloc[1:,i], X)
            result = model.fit()
            lamda = result.params[1]
            HL = -np.log(2) / lamda

        # trading period 고려
            if (HL <= half_life_threshold) & (HL >= 1):
                hl_screened_list.append(hurst_screened_list[i])

        spread_df = spread_df[hl_screened_list]

        # 6. mean-reverting freq이 충분히 자주 발생하는지 스크리닝
        freq_screened_list = []

        for j in range(len(spread_df.columns)):

            cnt = 0

            for i in range(len(spread_df.index)):

                if i == len(spread_df.index) -1:
                    break

                elif spread_df.iloc[i+1,j] >= spread_df.iloc[i,j]:
                    if (spread_df.mean()[j] >= spread_df.iloc[i,j]) & (spread_df.mean()[j] <= spread_df.iloc[i+1,j]):
                        cnt += 1

                else:
                    if (spread_df.mean()[j] >= spread_df.iloc[i+1,j]) & (spread_df.mean()[j] <= spread_df.iloc[i,j]):
                        cnt += 1
            
            if cnt >= mean_reverting_freq:
                freq_screened_list.append(hl_screened_list[j])

        selected_pair.append(freq_screened_list)

    return selected_pair

# %%
Pair_selection(clusters_viz_list=clusters_viz_list, inverse_threshold=0.1, coint_pvalue_threshold=0.05, hurst_threshold=0.5, half_life_threshold=30, mean_reverting_freq=12)
# Out:
# 100%|██████████| 3/3 [00:00<00:00, 226.23it/s]
# 100%|██████████| 3/3 [00:00<00:00, 209.32it/s]
# 100%|██████████| 3/3 [00:00<00:00, 211.91it/s]
# 100%|██████████| 10/10 [00:00<00:00, 246.68it/s]
# 100%|██████████| 10/10 [00:00<00:00, 258.67it/s]
# 100%|██████████| 15/15 [00:00<00:00, 266.10it/s]
# 100%|██████████| 85078/85078 [1:49:24<00:00, 12.96it/s]
# /var/folders/0k/zyr795gx3hl6x1nytrrntcnc0000gn/T/ipykernel_54024/944951854.py:34: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   spread_df[x] = close_df[x[0]] - close_df[x[1]]
# /var/folders/0k/zyr795gx3hl6x1nytrrntcnc0000gn/T/ipykernel_54024/944951854.py:34: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   spread_df[x] = close_df[x[0]] - close_df[x[1]]
# /var/folders/0k/zyr795gx3hl6x1nytrrntcnc0000gn/T/ipykernel_54024/944951854.py:34: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   spread_df[x] = close_df[x[0]] - close_df[x[1]]
# /var/folders/0k/zyr795gx3hl6x1nytrrntcnc0000gn/T/ipykernel_54024/944951854.py:34: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   spread_df[x] = close_df[x[0]] - close_df[x[1]]
# /var/folders/0k/zyr795gx3hl6x1nytrrntcnc0000gn/T/ipykernel_54024/944951854.py:34: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   spread_df[x] = close_df[x[0]] - close_df[x[1]]
# /var/folders/0k/zyr795gx3hl6x1nytrrntcnc0000gn/T/ipykernel_54024/944951854.py:34: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   spread_df[x] = close_df[x[0]] - close_df[x[1]]
# /var/folders/0k/zyr795gx3hl6x1nytrrntcnc0000gn/T/ipykernel_54024/944951854.py:34: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   spread_df[x] = close_df[x[0]] - close_df[x[1]]
# /var/folders/0k/zyr795gx3hl6x1nytrrntcnc0000gn/T/ipykernel_54024/944951854.py:34: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   spread_df[x] = close_df[x[0]] - close_df[x[1]]
# /var/folders/0k/zyr795gx3hl6x1nytrrntcnc0000gn/T/ipykernel_54024/944951854.py:34: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   spread_df[x] = close_df[x[0]] - close_df[x[1]]
# /var/folders/0k/zyr795gx3hl6x1nytrrntcnc0000gn/T/ipykernel_54024/944951854.py:34: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   spread_df[x] = close_df[x[0]] - close_df[x[1]]
# /var/folders/0k/zyr795gx3hl6x1nytrrntcnc0000gn/T/ipykernel_54024/944951854.py:34: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   spread_df[x] = close_df[x[0]] - close_df[x[1]]
# /var/folders/0k/zyr795gx3hl6x1nytrrntcnc0000gn/T/ipykernel_54024/944951854.py:34: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   spread_df[x] = close_df[x[0]] - close_df[x[1]]
# /var/folders/0k/zyr795gx3hl6x1nytrrntcnc0000gn/T/ipykernel_54024/944951854.py:34: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   spread_df[x] = close_df[x[0]] - close_df[x[1]]
# /var/folders/0k/zyr795gx3hl6x1nytrrntcnc0000gn/T/ipykernel_54024/944951854.py:34: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   spread_df[x] = close_df[x[0]] - close_df[x[1]]
# /var/folders/0k/zyr795gx3hl6x1nytrrntcnc0000gn/T/ipykernel_54024/944951854.py:34: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   spread_df[x] = close_df[x[0]] - close_df[x[1]]
# /var/folders/0k/zyr795gx3hl6x1nytrrntcnc0000gn/T/ipykernel_54024/944951854.py:34: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   spread_df[x] = close_df[x[0]] - close_df[x[1]]
# /var/folders/0k/zyr795gx3hl6x1nytrrntcnc0000gn/T/ipykernel_54024/944951854.py:34: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   spread_df[x] = close_df[x[0]] - close_df[x[1]]
# /var/folders/0k/zyr795gx3hl6x1nytrrntcnc0000gn/T/ipykernel_54024/944951854.py:34: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   spread_df[x] = close_df[x[0]] - close_df[x[1]]
# /var/folders/0k/zyr795gx3hl6x1nytrrntcnc0000gn/T/ipykernel_54024/944951854.py:34: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   spread_df[x] = close_df[x[0]] - close_df[x[1]]
# /var/folders/0k/zyr795gx3hl6x1nytrrntcnc0000gn/T/ipykernel_54024/944951854.py:34: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   spread_df[x] = close_df[x[0]] - close_df[x[1]]
# /var/folders/0k/zyr795gx3hl6x1nytrrntcnc0000gn/T/ipykernel_54024/944951854.py:34: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   spread_df[x] = close_df[x[0]] - close_df[x[1]]
# /var/folders/0k/zyr795gx3hl6x1nytrrntcnc0000gn/T/ipykernel_54024/944951854.py:34: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   spread_df[x] = close_df[x[0]] - close_df[x[1]]
# /var/folders/0k/zyr795gx3hl6x1nytrrntcnc0000gn/T/ipykernel_54024/944951854.py:34: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   spread_df[x] = close_df[x[0]] - close_df[x[1]]
# /var/folders/0k/zyr795gx3hl6x1nytrrntcnc0000gn/T/ipykernel_54024/944951854.py:34: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   spread_df[x] = close_df[x[0]] - close_df[x[1]]
# /var/folders/0k/zyr795gx3hl6x1nytrrntcnc0000gn/T/ipykernel_54024/944951854.py:34: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   spread_df[x] = close_df[x[0]] - close_df[x[1]]
# /var/folders/0k/zyr795gx3hl6x1nytrrntcnc0000gn/T/ipykernel_54024/944951854.py:34: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   spread_df[x] = close_df[x[0]] - close_df[x[1]]
# /var/folders/0k/zyr795gx3hl6x1nytrrntcnc0000gn/T/ipykernel_54024/944951854.py:34: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   spread_df[x] = close_df[x[0]] - close_df[x[1]]
# /var/folders/0k/zyr795gx3hl6x1nytrrntcnc0000gn/T/ipykernel_54024/944951854.py:34: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   spread_df[x] = close_df[x[0]] - close_df[x[1]]
# /var/folders/0k/zyr795gx3hl6x1nytrrntcnc0000gn/T/ipykernel_54024/944951854.py:34: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   spread_df[x] = close_df[x[0]] - close_df[x[1]]
# /var/folders/0k/zyr795gx3hl6x1nytrrntcnc0000gn/T/ipykernel_54024/944951854.py:34: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   spread_df[x] = close_df[x[0]] - close_df[x[1]]
# /var/folders/0k/zyr795gx3hl6x1nytrrntcnc0000gn/T/ipykernel_54024/944951854.py:34: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   spread_df[x] = close_df[x[0]] - close_df[x[1]]
# /var/folders/0k/zyr795gx3hl6x1nytrrntcnc0000gn/T/ipykernel_54024/944951854.py:34: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   spread_df[x] = close_df[x[0]] - close_df[x[1]]
# /var/folders/0k/zyr795gx3hl6x1nytrrntcnc0000gn/T/ipykernel_54024/944951854.py:34: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   spread_df[x] = close_df[x[0]] - close_df[x[1]]
# /var/folders/0k/zyr795gx3hl6x1nytrrntcnc0000gn/T/ipykernel_54024/944951854.py:34: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   spread_df[x] = close_df[x[0]] - close_df[x[1]]
# /var/folders/0k/zyr795gx3hl6x1nytrrntcnc0000gn/T/ipykernel_54024/944951854.py:34: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   spread_df[x] = close_df[x[0]] - close_df[x[1]]
# /var/folders/0k/zyr795gx3hl6x1nytrrntcnc0000gn/T/ipykernel_54024/944951854.py:34: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   spread_df[x] = close_df[x[0]] - close_df[x[1]]
# /var/folders/0k/zyr795gx3hl6x1nytrrntcnc0000gn/T/ipykernel_54024/944951854.py:34: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   spread_df[x] = close_df[x[0]] - close_df[x[1]]
# /var/folders/0k/zyr795gx3hl6x1nytrrntcnc0000gn/T/ipykernel_54024/944951854.py:34: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   spread_df[x] = close_df[x[0]] - close_df[x[1]]
# /var/folders/0k/zyr795gx3hl6x1nytrrntcnc0000gn/T/ipykernel_54024/944951854.py:34: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   spread_df[x] = close_df[x[0]] - close_df[x[1]]
# /var/folders/0k/zyr795gx3hl6x1nytrrntcnc0000gn/T/ipykernel_54024/944951854.py:34: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   spread_df[x] = close_df[x[0]] - close_df[x[1]]
# /var/folders/0k/zyr795gx3hl6x1nytrrntcnc0000gn/T/ipykernel_54024/944951854.py:34: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   spread_df[x] = close_df[x[0]] - close_df[x[1]]
# /var/folders/0k/zyr795gx3hl6x1nytrrntcnc0000gn/T/ipykernel_54024/944951854.py:34: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   spread_df[x] = close_df[x[0]] - close_df[x[1]]
# /var/folders/0k/zyr795gx3hl6x1nytrrntcnc0000gn/T/ipykernel_54024/944951854.py:34: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   spread_df[x] = close_df[x[0]] - close_df[x[1]]
# /var/folders/0k/zyr795gx3hl6x1nytrrntcnc0000gn/T/ipykernel_54024/944951854.py:34: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   spread_df[x] = close_df[x[0]] - close_df[x[1]]
# /var/folders/0k/zyr795gx3hl6x1nytrrntcnc0000gn/T/ipykernel_54024/944951854.py:34: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   spread_df[x] = close_df[x[0]] - close_df[x[1]]
# /var/folders/0k/zyr795gx3hl6x1nytrrntcnc0000gn/T/ipykernel_54024/944951854.py:34: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   spread_df[x] = close_df[x[0]] - close_df[x[1]]
# /var/folders/0k/zyr795gx3hl6x1nytrrntcnc0000gn/T/ipykernel_54024/944951854.py:34: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   spread_df[x] = close_df[x[0]] - close_df[x[1]]
# /var/folders/0k/zyr795gx3hl6x1nytrrntcnc0000gn/T/ipykernel_54024/944951854.py:34: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   spread_df[x] = close_df[x[0]] - close_df[x[1]]
# /var/folders/0k/zyr795gx3hl6x1nytrrntcnc0000gn/T/ipykernel_54024/944951854.py:34: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   spread_df[x] = close_df[x[0]] - close_df[x[1]]
# /var/folders/0k/zyr795gx3hl6x1nytrrntcnc0000gn/T/ipykernel_54024/944951854.py:34: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   spread_df[x] = close_df[x[0]] - close_df[x[1]]
# /var/folders/0k/zyr795gx3hl6x1nytrrntcnc0000gn/T/ipykernel_54024/944951854.py:34: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   spread_df[x] = close_df[x[0]] - close_df[x[1]]
# /var/folders/0k/zyr795gx3hl6x1nytrrntcnc0000gn/T/ipykernel_54024/944951854.py:34: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   spread_df[x] = close_df[x[0]] - close_df[x[1]]
# /var/folders/0k/zyr795gx3hl6x1nytrrntcnc0000gn/T/ipykernel_54024/944951854.py:34: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   spread_df[x] = close_df[x[0]] - close_df[x[1]]
# /var/folders/0k/zyr795gx3hl6x1nytrrntcnc0000gn/T/ipykernel_54024/944951854.py:34: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   spread_df[x] = close_df[x[0]] - close_df[x[1]]
# /var/folders/0k/zyr795gx3hl6x1nytrrntcnc0000gn/T/ipykernel_54024/944951854.py:34: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   spread_df[x] = close_df[x[0]] - close_df[x[1]]
# /var/folders/0k/zyr795gx3hl6x1nytrrntcnc0000gn/T/ipykernel_54024/944951854.py:34: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   spread_df[x] = close_df[x[0]] - close_df[x[1]]
# /var/folders/0k/zyr795gx3hl6x1nytrrntcnc0000gn/T/ipykernel_54024/944951854.py:34: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   spread_df[x] = close_df[x[0]] - close_df[x[1]]
# /var/folders/0k/zyr795gx3hl6x1nytrrntcnc0000gn/T/ipykernel_54024/944951854.py:34: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   spread_df[x] = close_df[x[0]] - close_df[x[1]]
# /var/folders/0k/zyr795gx3hl6x1nytrrntcnc0000gn/T/ipykernel_54024/944951854.py:34: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   spread_df[x] = close_df[x[0]] - close_df[x[1]]
# /var/folders/0k/zyr795gx3hl6x1nytrrntcnc0000gn/T/ipykernel_54024/944951854.py:34: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   spread_df[x] = close_df[x[0]] - close_df[x[1]]
# /var/folders/0k/zyr795gx3hl6x1nytrrntcnc0000gn/T/ipykernel_54024/944951854.py:34: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   spread_df[x] = close_df[x[0]] - close_df[x[1]]
# /var/folders/0k/zyr795gx3hl6x1nytrrntcnc0000gn/T/ipykernel_54024/944951854.py:34: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   spread_df[x] = close_df[x[0]] - close_df[x[1]]
# /var/folders/0k/zyr795gx3hl6x1nytrrntcnc0000gn/T/ipykernel_54024/944951854.py:34: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   spread_df[x] = close_df[x[0]] - close_df[x[1]]
# /var/folders/0k/zyr795gx3hl6x1nytrrntcnc0000gn/T/ipykernel_54024/944951854.py:34: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   spread_df[x] = close_df[x[0]] - close_df[x[1]]
# /var/folders/0k/zyr795gx3hl6x1nytrrntcnc0000gn/T/ipykernel_54024/944951854.py:34: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   spread_df[x] = close_df[x[0]] - close_df[x[1]]
# /var/folders/0k/zyr795gx3hl6x1nytrrntcnc0000gn/T/ipykernel_54024/944951854.py:34: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   spread_df[x] = close_df[x[0]] - close_df[x[1]]
# /var/folders/0k/zyr795gx3hl6x1nytrrntcnc0000gn/T/ipykernel_54024/944951854.py:34: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   spread_df[x] = close_df[x[0]] - close_df[x[1]]
# /var/folders/0k/zyr795gx3hl6x1nytrrntcnc0000gn/T/ipykernel_54024/944951854.py:34: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   spread_df[x] = close_df[x[0]] - close_df[x[1]]
# /var/folders/0k/zyr795gx3hl6x1nytrrntcnc0000gn/T/ipykernel_54024/944951854.py:34: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   spread_df[x] = close_df[x[0]] - close_df[x[1]]
# /var/folders/0k/zyr795gx3hl6x1nytrrntcnc0000gn/T/ipykernel_54024/944951854.py:34: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   spread_df[x] = close_df[x[0]] - close_df[x[1]]
# /var/folders/0k/zyr795gx3hl6x1nytrrntcnc0000gn/T/ipykernel_54024/944951854.py:34: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   spread_df[x] = close_df[x[0]] - close_df[x[1]]
# /var/folders/0k/zyr795gx3hl6x1nytrrntcnc0000gn/T/ipykernel_54024/944951854.py:34: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   spread_df[x] = close_df[x[0]] - close_df[x[1]]
# /var/folders/0k/zyr795gx3hl6x1nytrrntcnc0000gn/T/ipykernel_54024/944951854.py:34: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   spread_df[x] = close_df[x[0]] - close_df[x[1]]
# /var/folders/0k/zyr795gx3hl6x1nytrrntcnc0000gn/T/ipykernel_54024/944951854.py:34: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   spread_df[x] = close_df[x[0]] - close_df[x[1]]
# /var/folders/0k/zyr795gx3hl6x1nytrrntcnc0000gn/T/ipykernel_54024/944951854.py:34: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   spread_df[x] = close_df[x[0]] - close_df[x[1]]
# /var/folders/0k/zyr795gx3hl6x1nytrrntcnc0000gn/T/ipykernel_54024/944951854.py:34: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   spread_df[x] = close_df[x[0]] - close_df[x[1]]
# /var/folders/0k/zyr795gx3hl6x1nytrrntcnc0000gn/T/ipykernel_54024/944951854.py:34: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   spread_df[x] = close_df[x[0]] - close_df[x[1]]
# /var/folders/0k/zyr795gx3hl6x1nytrrntcnc0000gn/T/ipykernel_54024/944951854.py:34: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   spread_df[x] = close_df[x[0]] - close_df[x[1]]
# /var/folders/0k/zyr795gx3hl6x1nytrrntcnc0000gn/T/ipykernel_54024/944951854.py:34: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   spread_df[x] = close_df[x[0]] - close_df[x[1]]
# /var/folders/0k/zyr795gx3hl6x1nytrrntcnc0000gn/T/ipykernel_54024/944951854.py:34: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   spread_df[x] = close_df[x[0]] - close_df[x[1]]
# /var/folders/0k/zyr795gx3hl6x1nytrrntcnc0000gn/T/ipykernel_54024/944951854.py:34: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   spread_df[x] = close_df[x[0]] - close_df[x[1]]
# /var/folders/0k/zyr795gx3hl6x1nytrrntcnc0000gn/T/ipykernel_54024/944951854.py:34: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   spread_df[x] = close_df[x[0]] - close_df[x[1]]
# /var/folders/0k/zyr795gx3hl6x1nytrrntcnc0000gn/T/ipykernel_54024/944951854.py:34: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   spread_df[x] = close_df[x[0]] - close_df[x[1]]
# /var/folders/0k/zyr795gx3hl6x1nytrrntcnc0000gn/T/ipykernel_54024/944951854.py:34: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   spread_df[x] = close_df[x[0]] - close_df[x[1]]
# /var/folders/0k/zyr795gx3hl6x1nytrrntcnc0000gn/T/ipykernel_54024/944951854.py:34: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   spread_df[x] = close_df[x[0]] - close_df[x[1]]
# /var/folders/0k/zyr795gx3hl6x1nytrrntcnc0000gn/T/ipykernel_54024/944951854.py:34: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   spread_df[x] = close_df[x[0]] - close_df[x[1]]
# /var/folders/0k/zyr795gx3hl6x1nytrrntcnc0000gn/T/ipykernel_54024/944951854.py:34: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   spread_df[x] = close_df[x[0]] - close_df[x[1]]
# /var/folders/0k/zyr795gx3hl6x1nytrrntcnc0000gn/T/ipykernel_54024/944951854.py:34: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   spread_df[x] = close_df[x[0]] - close_df[x[1]]
# /var/folders/0k/zyr795gx3hl6x1nytrrntcnc0000gn/T/ipykernel_54024/944951854.py:34: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   spread_df[x] = close_df[x[0]] - close_df[x[1]]
# /var/folders/0k/zyr795gx3hl6x1nytrrntcnc0000gn/T/ipykernel_54024/944951854.py:34: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   spread_df[x] = close_df[x[0]] - close_df[x[1]]
# /var/folders/0k/zyr795gx3hl6x1nytrrntcnc0000gn/T/ipykernel_54024/944951854.py:34: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   spread_df[x] = close_df[x[0]] - close_df[x[1]]
# /var/folders/0k/zyr795gx3hl6x1nytrrntcnc0000gn/T/ipykernel_54024/944951854.py:34: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   spread_df[x] = close_df[x[0]] - close_df[x[1]]
# /var/folders/0k/zyr795gx3hl6x1nytrrntcnc0000gn/T/ipykernel_54024/944951854.py:34: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   spread_df[x] = close_df[x[0]] - close_df[x[1]]
# /var/folders/0k/zyr795gx3hl6x1nytrrntcnc0000gn/T/ipykernel_54024/944951854.py:34: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   spread_df[x] = close_df[x[0]] - close_df[x[1]]
# /var/folders/0k/zyr795gx3hl6x1nytrrntcnc0000gn/T/ipykernel_54024/944951854.py:34: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   spread_df[x] = close_df[x[0]] - close_df[x[1]]
# /var/folders/0k/zyr795gx3hl6x1nytrrntcnc0000gn/T/ipykernel_54024/944951854.py:34: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   spread_df[x] = close_df[x[0]] - close_df[x[1]]
# /var/folders/0k/zyr795gx3hl6x1nytrrntcnc0000gn/T/ipykernel_54024/944951854.py:34: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   spread_df[x] = close_df[x[0]] - close_df[x[1]]
# /var/folders/0k/zyr795gx3hl6x1nytrrntcnc0000gn/T/ipykernel_54024/944951854.py:34: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   spread_df[x] = close_df[x[0]] - close_df[x[1]]
# /var/folders/0k/zyr795gx3hl6x1nytrrntcnc0000gn/T/ipykernel_54024/944951854.py:34: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   spread_df[x] = close_df[x[0]] - close_df[x[1]]
# /var/folders/0k/zyr795gx3hl6x1nytrrntcnc0000gn/T/ipykernel_54024/944951854.py:34: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   spread_df[x] = close_df[x[0]] - close_df[x[1]]
# /var/folders/0k/zyr795gx3hl6x1nytrrntcnc0000gn/T/ipykernel_54024/944951854.py:34: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   spread_df[x] = close_df[x[0]] - close_df[x[1]]
# /var/folders/0k/zyr795gx3hl6x1nytrrntcnc0000gn/T/ipykernel_54024/944951854.py:34: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   spread_df[x] = close_df[x[0]] - close_df[x[1]]
# /var/folders/0k/zyr795gx3hl6x1nytrrntcnc0000gn/T/ipykernel_54024/944951854.py:34: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   spread_df[x] = close_df[x[0]] - close_df[x[1]]
# /var/folders/0k/zyr795gx3hl6x1nytrrntcnc0000gn/T/ipykernel_54024/944951854.py:34: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   spread_df[x] = close_df[x[0]] - close_df[x[1]]
# /var/folders/0k/zyr795gx3hl6x1nytrrntcnc0000gn/T/ipykernel_54024/944951854.py:34: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   spread_df[x] = close_df[x[0]] - close_df[x[1]]
# /var/folders/0k/zyr795gx3hl6x1nytrrntcnc0000gn/T/ipykernel_54024/944951854.py:34: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   spread_df[x] = close_df[x[0]] - close_df[x[1]]
# /var/folders/0k/zyr795gx3hl6x1nytrrntcnc0000gn/T/ipykernel_54024/944951854.py:34: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   spread_df[x] = close_df[x[0]] - close_df[x[1]]
# /var/folders/0k/zyr795gx3hl6x1nytrrntcnc0000gn/T/ipykernel_54024/944951854.py:34: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   spread_df[x] = close_df[x[0]] - close_df[x[1]]
# /var/folders/0k/zyr795gx3hl6x1nytrrntcnc0000gn/T/ipykernel_54024/944951854.py:34: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   spread_df[x] = close_df[x[0]] - close_df[x[1]]
# /var/folders/0k/zyr795gx3hl6x1nytrrntcnc0000gn/T/ipykernel_54024/944951854.py:34: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   spread_df[x] = close_df[x[0]] - close_df[x[1]]
# /var/folders/0k/zyr795gx3hl6x1nytrrntcnc0000gn/T/ipykernel_54024/944951854.py:34: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   spread_df[x] = close_df[x[0]] - close_df[x[1]]
# /var/folders/0k/zyr795gx3hl6x1nytrrntcnc0000gn/T/ipykernel_54024/944951854.py:34: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   spread_df[x] = close_df[x[0]] - close_df[x[1]]
# /var/folders/0k/zyr795gx3hl6x1nytrrntcnc0000gn/T/ipykernel_54024/944951854.py:34: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   spread_df[x] = close_df[x[0]] - close_df[x[1]]
# /var/folders/0k/zyr795gx3hl6x1nytrrntcnc0000gn/T/ipykernel_54024/944951854.py:34: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   spread_df[x] = close_df[x[0]] - close_df[x[1]]
# /var/folders/0k/zyr795gx3hl6x1nytrrntcnc0000gn/T/ipykernel_54024/944951854.py:34: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   spread_df[x] = close_df[x[0]] - close_df[x[1]]
# /var/folders/0k/zyr795gx3hl6x1nytrrntcnc0000gn/T/ipykernel_54024/944951854.py:34: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   spread_df[x] = close_df[x[0]] - close_df[x[1]]
# ...
#   ('SCZ', 'ADRE'),
#   ('EWZ', 'VEU'),
#   ('PEZ', 'XRT'),
#   ('EWC', 'XRT'),
#   ('EWC', 'DVY'),
#   ('VOE', 'UCC'),
#   ('EES', 'VOE'),
#   ('FAB', 'IGM'),
#   ('SPXL', 'EWJ'),
#   ('VNM', 'USD'),
#   ('VNM', 'DXJ'),
#   ('ILF', 'AIA'),
#   ('SCJ', 'TNA'),
#   ('XLK', 'IWS'),
#   ('VOE', 'IYW'),
#   ('RWL', 'IXN'),
#   ('DVY', 'FXG'),
#   ('KXI', 'CVY'),
#   ('EWZ', 'IHE'),
#   ('AFK', 'ADRE'),
#   ('IYJ', 'MDYV'),
#   ('DFE', 'IHE'),
#   ('DIA', 'XLK'),
#   ('KXI', 'EEM'),
#   ('AFK', 'IYK'),
#   ('GWX', 'AIA'),
#   ('IUSV', 'SCJ'),
#   ('SCZ', 'EMIF'),
#   ('PBE', 'FTA'),
#   ('EWC', 'XPH'),
#   ('JPXN', 'XBI'),
#   ('IWS', 'XRT'),
#   ('MGC', 'IWL'),
#   ('EWZ', 'EPP'),
#   ('WOOD', 'XLK'),
#   ('FXZ', 'IWS'),
#   ('CSD', 'XRT'),
#   ('SCJ', 'SLYV'),
#   ('AFK', 'PIZ'),
#   ('QQXT', 'XLK'),
#   ('PKW', 'EWC'),
#   ('SPEM', 'EWH'),
#   ('PSJ', 'ISCG'),
#   ('KXI', 'PIZ'),
#   ('FXZ', 'VOE'),
#   ('XRT', 'MDYV'),
#   ('QABA', 'KRE'),
#   ('IUSG', 'XLK'),
#   ('VNM', 'RXL'),
#   ('PBE', 'FXG'),
#   ('SCJ', 'IWC'),
#   ('PSL', 'EVX'),
#   ('IWV', 'IGM'),
#   ('IGN', 'IMCB'),
#   ('XSVM', 'PBS'),
#   ('PSJ', 'IMCB'),
#   ('RYF', 'DFJ'),
#   ('FXD', 'SLY'),
#   ('PSJ', 'IJK'),
#   ('FXD', 'EES'),
#   ('SPEM', 'EWD'),
#   ('FAD', 'PSJ'),
#   ('DGT', 'VHT'),
#   ('EWA', 'VPL'),
#   ('EES', 'IWR'),
#   ('DNL', 'VEU'),
#   ('IGM', 'VTI'),
#   ('VDC', 'PYZ'),
#   ('ILCB', 'IXN'),
#   ('ILCG', 'FTCS'),
#   ('ONEQ', 'SCHB'),
#   ('IWD', 'SCJ'),
#   ('IGN', 'FXZ'),
#   ('XBI', 'TOK'),
#   ('VNM', 'XSD'),
#   ('SDY', 'CUT'),
#   ('EWD', 'VWO'),
#   ('VNM', 'PPA'),
#   ('VFH', 'DFJ'),
#   ('XLI', 'IWS'),
#   ('XLI', 'MDYV'),
#   ('EWC', 'PEJ'),
#   ('VNM', 'KCE'),
#   ('SCJ', 'IJJ'),
#   ('QQXT', 'PBE'),
#   ('DVY', 'CUT'),
#   ('QCLN', 'IWL'),
#   ('VNM', 'XLV'),
#   ('PSJ', 'FNX'),
#   ('IGN', 'RSP'),
#   ('NORW', 'BKF'),
#   ('FNX', 'XRT'),
#   ('SCJ', 'SLY'),
#   ('QCLN', 'EWJ'),
#   ('JPXN', 'DGT'),
#   ('AFK', 'GWX'),
#   ('FAB', 'MVV'),
#   ('KXI', 'PXH'),
#   ('EZJ', 'IXC'),
#   ('ONEQ', 'SPTM'),
#   ('VNM', 'FXH'),
#   ('FVD', 'ADRE'),
#   ('WOOD', 'XPH'),
#   ('FGD', 'PID'),
#   ('IAI', 'PPA'),
#   ('IXN', 'UPRO'),
#   ('EEM', 'EWH'),
#   ('FTC', 'IJK'),
#   ('EZJ', 'XBI'),
#   ('XLK', 'FAB'),
#   ('VPU', 'IDU'),
#   ('VNM', 'PBS'),
#   ('ISCV', 'UCC'),
#   ('XLK', 'MVV'),
#   ('IJK', 'EWC'),
#   ('GII', 'DOL'),
#   ('VPU', 'PIN'),
#   ('QQQ', 'PYZ'),
#   ('PBE', 'RSP'),
#   ('VNM', 'TECL'),
#   ('XMMO', 'SLYG'),
#   ('IAT', 'QABA'),
#   ('NORW', 'VWO'),
#   ('VPL', 'DLS'),
#   ('PIZ', 'GWX'),
#   ('EES', 'PEZ'),
#   ('ILF', 'PJP'),
#   ('JPXN', 'RYH'),
#   ('ILF', 'EWH'),
#   ('VNM', 'DSI'),
#   ('PIZ', 'ADRE'),
#   ('PXH', 'EMIF'),
#   ('SDY', 'XPH'),
#   ('EWY', 'AIVL'),
#   ('RGI', 'EWC'),
#   ('EZJ', 'EWJ'),
#   ('IGN', 'RTM'),
#   ('IJJ', 'IYW'),
#   ('GRID', 'EWJ'),
#   ('IVE', 'SCJ'),
#   ('ISCG', 'IMCG'),
#   ('QCLN', 'ILCV'),
#   ('GRID', 'FTCS'),
#   ('SDY', 'AFK'),
#   ('XLK', 'FXZ'),
#   ('IGM', 'IWB'),
#   ('VT', 'ADRE'),
#   ('RGI', 'VOE'),
#   ('EZJ', 'RYH'),
#   ('NORW', 'PJP'),
#   ('RYT', 'VIS'),
#   ('EWZ', 'CVY'),
#   ('VNM', 'IAI'),
#   ('XNTK', 'IGE'),
#   ('FXZ', 'EWC'),
#   ('XRT', 'VOE'),
#   ('FTA', 'IYW'),
#   ('CZA', 'LTL'),
#   ('XLK', 'IJJ'),
#   ('EES', 'FXZ'),
#   ('EMIF', 'CWI'),
#   ('KXI', 'ADRE'),
#   ('EMIF', 'EWU'),
#   ('PSJ', 'XSMO'),
#   ('PBW', 'EFO'),
#   ('VPU', 'EPI'),
#   ('VNM', 'SAA'),
#   ('KXI', 'GWX'),
#   ('SCJ', 'ISCB'),
#   ('QQQ', 'VO'),
#   ('KXI', 'DNL'),
#   ('WTV', 'EWJ'),
#   ('UPRO', 'EWJ'),
#   ('ISCG', 'IMCB'),
#   ('RPV', 'DFJ'),
#   ('PSJ', 'XRT'),
#   ('SCJ', 'MVV'),
#   ('IWV', 'XNTK'),
#   ('FXZ', 'QQEW'),
#   ('EWZ', 'VGK'),
#   ('QQXT', 'DTD'),
#   ('ILF', 'EWY'),
#   ('VNM', 'FTCS'),
#   ('EWC', 'IMCG'),
#   ('JPXN', 'VHT'),
#   ('SPXL', 'WTV'),
#   ('EWC', 'ISCG'),
#   ('RYT', 'RXI'),
#   ('EWZ', 'EWU'),
#   ('SCJ', 'VTV'),
#   ('XBI', 'ILCV'),
#   ('EWT', 'PJP'),
#   ('EWC', 'DON'),
#   ('IXN', 'SSO'),
#   ('ERTH', 'QCLN'),
#   ('GRID', 'QCLN'),
#   ('IGN', 'VIS'),
#   ('KXI', 'IHE'),
#   ('XLK', 'EZM'),
#   ('ILF', 'IEUS'),
#   ('EZJ', 'XLG'),
#   ('XNTK', 'VV'),
#   ('IGM', 'IJJ'),
#   ('XLP', 'ADRE'),
#   ('IHE', 'EPP'),
#   ('EWH', 'IXP'),
#   ('VDC', 'AIA'),
#   ('VEA', 'IDV'),
#   ('ONEQ', 'EQWL'),
#   ('EWZ', 'NORW'),
#   ('ADRE', 'UGE'),
#   ('IEUS', 'ADRE'),
#   ('PSJ', 'IWR'),
#   ('IGM', 'VV'),
#   ('VNM', 'UPRO'),
#   ('ISCV', 'XRT'),
#   ('EWD', 'IYZ'),
#   ('FVD', 'XLP'),
#   ('VNM', 'RWK'),
#   ('VNM', 'SLYV'),
#   ('VNM', 'PHO'),
#   ('VNM', 'SUSA'),
#   ('SCZ', 'ILF'),
#   ('AFK', 'DVY'),
#   ('AAXJ', 'EWD'),
#   ('EWA', 'XBI'),
#   ('XNTK', 'IYY'),
#   ('SCHA', 'FXR'),
#   ('IWD', 'IXN'),
#   ('PDP', 'PSL'),
#   ('EWZ', 'SCHF'),
#   ('SPEM', 'VDC'),
#   ('AIVI', 'CHII'),
#   ('VNM', 'IMCV'),
#   ('PRF', 'SCJ'),
#   ('VNM', 'IXN'),
#   ('VNM', 'MGV'),
#   ('IGN', 'DIA'),
#   ('DIM', 'EWZ'),
#   ('IJJ', 'IYJ'),
#   ('EWD', 'PJP'),
#   ('XLK', 'XLP'),
#   ('SCZ', 'IHE'),
#   ('DWX', 'IEV'),
#   ('EWC', 'IWS'),
#   ('EWT', 'EWY'),
#   ('WTV', 'IXN'),
#   ('RCD', 'VBR'),
#   ('DLS', 'EDC'),
#   ('SPYG', 'IYW'),
#   ('XNTK', 'IWB'),
#   ('EWZ', 'AFK'),
#   ('SPYV', 'SCJ'),
#   ('VNM', 'EQWL'),
#   ('VNM', 'IJJ'),
#   ('ITOT', 'XLK'),
#   ('VNM', 'VTV'),
#   ('GRID', 'ILCV'),
#   ('IWS', 'IYW'),
#   ('XBI', 'EPS'),
#   ('SCJ', 'SOXX'),
#   ('QCLN', 'SCHB'),
#   ('EZA', 'PNQI'),
#   ('RPV', 'PFI'),
#   ('PSJ', 'XMMO'),
#   ('AIVI', 'EMIF'),
#   ('VNM', 'SSO'),
#   ('EES', 'IYJ'),
#   ('EWZ', 'AIVI'),
#   ('PBE', 'FEX'),
#   ('FPX', 'XLK'),
#   ('PSJ', 'IWP'),
#   ('VNM', 'ISCB'),
#   ('SCJ', 'IMCV'),
#   ('SDY', 'XLK'),
#   ('EWC', 'RSP'),
#   ('FIW', 'FDM'),
#   ('QQEW', 'FEX'),
#   ('SPY', 'XNTK'),
#   ('DFE', 'EWZ'),
#   ('ROM', 'SPYV'),
#   ('XLK', 'SLY'),
#   ('EWW', 'EVX'),
#   ('PBE', 'QQEW'),
#   ('FXO', 'QLD'),
#   ('PDP', 'DVY'),
#   ('CSD', 'IYC'),
#   ('IXN', 'VTV'),
#   ('IOO', 'XBI'),
#   ('ONEQ', 'ITOT'),
#   ('VNM', 'UCC'),
#   ('RWJ', 'SLYV'),
#   ('IGN', 'QQEW'),
#   ('VNM', 'MVV'),
#   ('SPDW', 'XBI'),
#   ('IDU', 'PIE'),
#   ('QQEW', 'IMCB'),
#   ('IGN', 'IYJ'),
#   ('VNM', 'IWL'),
#   ('IWF', 'IGE'),
#   ('XNTK', 'VTI'),
#   ('IGN', 'FAB'),
#   ('IGN', 'XLI'),
#   ('ILF', 'EWD'),
#   ('VNM', 'SLY'),
#   ('VNM', 'FXG'),
#   ('VNM', 'EPS'),
#   ('XLF', 'DFJ'),
#   ('EES', 'FXR'),
#   ('QQQ', 'RYT'),
#   ('QCLN', 'PSP'),
#   ('UXI', 'SCJ'),
#   ('WOOD', 'QLD'),
#   ('FTC', 'PSJ'),
#   ('CSD', 'FXR'),
#   ('QCLN', 'SCHV'),
#   ('VPU', 'INDY'),
#   ('CSM', 'QCLN'),
#   ('ADRE', 'PJP'),
#   ('VNM', 'KIE'),
#   ('RPG', 'PYZ'),
#   ('DLS', 'ACWI'),
#   ('XBI', 'FTCS'),
#   ('RWL', 'VTV'),
#   ('SPY', 'IGM'),
#   ('VNM', 'SCHG'),
#   ('VNM', 'XMVM'),
#   ('VNM', 'IYC'),
#   ('VPL', 'XBI'),
#   ('IHE', 'DNL'),
#   ('ILCB', 'PHO'),
#   ('DWM', 'IGF'),
#   ('VNM', 'PWV'),
#   ('RWL', 'SCJ'),
#   ('DHS', 'SPEM'),
#   ('EWU', 'VEA'),
#   ('VNM', 'UGE'),
#   ('IJJ', 'VGT'),
#   ('EES', 'MVV'),
#   ('VIS', 'XRT'),
#   ('PSI', 'FDM'),
#   ('ONEQ', 'IYW'),
#   ('PSJ', 'QTEC'),
#   ('VNM', 'SPYG'),
#   ('PSJ', 'EES'),
#   ('CSD', 'MDYV'),
#   ('SPEM', 'EEM'),
#   ('RWK', 'SCJ'),
#   ('VNM', 'SCHB'),
#   ('DEW', 'IGF'),
#   ('EMIF', 'VEA'),
#   ('IYY', 'XLK'),
#   ('VNM', 'IYW'),
#   ('KBE', 'KRE'),
#   ('ONEQ', 'VOE'),
#   ('EWZ', 'VEA'),
#   ('VNM', 'EZM'),
#   ('SPY', 'XME'),
#   ('WOOD', 'QQQ'),
#   ('IVE', 'IXN'),
#   ('RZG', 'RYT'),
#   ('FAD', 'XRT'),
#   ('DFE', 'ILF'),
#   ('PXE', 'EVX'),
#   ('JPXN', 'OEF'),
#   ('VNM', 'IWP'),
#   ('PBE', 'IWR'),
#   ('EWC', 'FNX'),
#   ('RGI', 'VB'),
#   ('XRT', 'XLY'),
#   ('IVV', 'IGM'),
#   ('AAXJ', 'DEF'),
#   ('RYT', 'MDYG'),
#   ('AFK', 'PYZ'),
#   ('GRES', 'PJP'),
#   ('PXH', 'GWX'),
#   ('VNM', 'SCHX'),
#   ('DIM', 'IHE'),
#   ('VNM', 'XHB'),
#   ('XSVM', 'SCJ'),
#   ('EWC', 'EZM'),
#   ('XLK', 'PSP'),
#   ('EWZ', 'PGJ'),
#   ('FAB', 'XRT'),
#   ('AFK', 'AIVL'),
#   ('AIA', 'AIVL'),
#   ('VNM', 'VYM'),
#   ('GRID', 'IXN'),
#   ('ILCG', 'SUSA'),
#   ('SPLG', 'IYW'),
#   ('VNM', 'SCHV'),
#   ('IWX', 'SCJ'),
#   ('DFE', 'HAP'),
#   ('SCJ', 'IYJ'),
#   ('PSJ', 'MDYG'),
#   ('SPEM', 'DEF'),
#   ('PRF', 'IGM'),
#   ('IHE', 'EFG'),
#   ('SCJ', 'XSD'),
#   ('EZJ', 'DGT'),
#   ('PSJ', 'PEJ'),
#   ('VPU', 'PIE'),
#   ('SCJ', 'FXR'),
#   ('RYT', 'VOE'),
#   ('FXZ', 'FAB'),
#   ('RYT', 'RSP'),
#   ('GRID', 'SUSA'),
#   ('MDYG', 'EWC'),
#   ('FXI', 'PGJ'),
#   ('SCJ', 'SCHV'),
#   ('QCLN', 'UPRO'),
#   ('VNM', 'IYJ'),
#   ('VNM', 'IWR'),
#   ('EWC', 'IYJ'),
#   ('VDE', 'IEZ'),
#   ('VNM', 'FXR'),
#   ('VIG', 'IGM'),
#   ('AIA', 'BJK'),
#   ('JPXN', 'IXC'),
#   ('PEZ', 'SLY'),
#   ('VNM', 'IMCG'),
#   ('MIDU', 'WTV'),
#   ('FXD', 'PSJ'),
#   ('ILCB', 'SCJ'),
#   ('EZM', 'IYW'),
#   ('MIDU', 'SCJ'),
#   ('XNTK', 'IVV'),
#   ('RYT', 'RGI'),
#   ('XLK', 'EQWL'),
#   ('DIM', 'DFE'),
#   ('IHE', 'VPL'),
#   ('GRID', 'FXH'),
#   ('ILF', 'BJK'),
#   ('VXF', 'RGI'),
#   ('PXH', 'EWG'),
#   ('SCJ', 'MGV'),
#   ('RYT', 'VB'),
#   ('IWM', 'PRFZ'),
#   ('VNM', 'FXL'),
#   ('SPEM', 'PJP'),
#   ('PXH', 'PJP'),
#   ('DLS', 'PXJ'),
#   ('IJJ', 'SLY'),
#   ('FXN', 'XNTK'),
#   ('PBE', 'IMCB'),
#   ('ILF', 'FXG'),
#   ('EES', 'XLK'),
#   ('FXO', 'WOOD'),
#   ('GRID', 'EWK'),
#   ('INDY', 'FNI'),
#   ('PDN', 'ADRE'),
#   ('VNM', 'PEY'),
#   ('EWJ', 'TECL'),
#   ('RYF', 'IMCV'),
#   ('EEM', 'EWD'),
#   ('ILCB', 'IWL'),
#   ('XME', 'IWB'),
#   ('DTH', 'BBH'),
#   ('VPL', 'IDV'),
#   ('VNM', 'ILCV'),
#   ('XBI', 'ACWI'),
#   ('RYT', 'FNX'),
#   ('EWG', 'PSP'),
#   ('IGN', 'MDYG'),
#   ('EWD', 'AIA'),
#   ('DFE', 'PXH'),
#   ('EZM', 'FXR'),
#   ('MGV', 'IXN'),
#   ('IHE', 'FGD'),
#   ('FXZ', 'IYJ'),
#   ('VNM', 'MDYV'),
#   ('FDM', 'SOXX'),
#   ('PFM', 'ADRE'),
#   ('RWK', 'FXH'),
#   ('XLK', 'PRF'),
#   ('VNM', 'FEX'),
#   ('QQEW', 'FTA'),
#   ('VNM', 'EWO'),
#   ('IJJ', 'XRT'),
#   ('VDC', 'EWC'),
#   ('GXC', 'EWH'),
#   ('EWZ', 'DEW'),
#   ('VNM', 'QTEC'),
#   ('RYT', 'IWS'),
#   ('XME', 'IWF'),
#   ('PBD', 'IYH'),
#   ('FXZ', 'FEX'),
#   ('DLN', 'AFK'),
#   ('IWV', 'XME'),
#   ('GII', 'CHII'),
#   ('VNM', 'DON'),
#   ('VNM', 'DGT'),
#   ('SPTM', 'SCHB'),
#   ('GRID', 'SSO'),
#   ('XLI', 'RTM'),
#   ('EWD', 'EWY'),
#   ('GRID', 'DGT'),
#   ('EWZ', 'IEUS'),
#   ('FXD', 'VOE'),
#   ('EZJ', 'TECL'),
#   ('WOOD', 'ADRE'),
#   ('IHE', 'PIZ'),
#   ('IJJ', 'FXH'),
#   ('ERTH', 'FTCS'),
#   ('VNM', 'IMCB'),
#   ('WTV', 'ILCB'),
#   ('WOOD', 'PFM'),
#   ('GRES', 'LTL'),
#   ('EES', 'IYW'),
#   ('VUG', 'IWF'),
#   ('EEM', 'DEF'),
#   ('EXI', 'UYM'),
#   ('VNM', 'DVY'),
#   ('ITA', 'PFI'),
#   ('DTD', 'XLK'),
#   ('IGN', 'EQL'),
#   ('RYT', 'EWW'),
#   ('VNM', 'PSP'),
#   ('PSL', 'CZA'),
#   ('PBE', 'XLP'),
#   ('EWA', 'EFA'),
#   ('PRN', 'EVX'),
#   ('XRT', 'SLY'),
#   ('EEM', 'GWX'),
#   ('SCHB', 'IYW'),
#   ('GRID', 'UPRO'),
#   ('XLP', 'EWC'),
#   ('XLG', 'EWJ'),
#   ('IGM', 'SLY'),
#   ('SPYV', 'IYW'),
#   ('ERTH', 'EWJ'),
#   ('XLP', 'ILF'),
#   ('KXI', 'SPEM'),
#   ('KXI', 'EWH'),
#   ('GRID', 'PSP'),
#   ('EMIF', 'ADRE'),
#   ('RYT', 'XRT'),
#   ('IMCV', 'UCC'),
#   ('XBI', 'UYM'),
#   ('IAT', 'IYG'),
#   ('EPI', 'RYU'),
#   ('FXD', 'IYJ'),
#   ('SCJ', 'RSP'),
#   ('EXI', 'IGM'),
#   ('FTC', 'PBE'),
#   ('SPTM', 'XLK'),
#   ('IGN', 'IWR'),
#   ('AFK', 'XPH'),
#   ('EWZ', 'PXF'),
#   ('IDU', 'EWH'),
#   ('EIS', 'IYH'),
#   ('GRID', 'EWO'),
#   ('VNM', 'XPH'),
#   ('RYJ', 'SCJ'),
#   ('PSI', 'SOXX'),
#   ('IHE', 'MXI'),
#   ('PSL', 'IYZ'),
#   ('IHE', 'EDC'),
#   ('EWJ', 'PHO'),
#   ('CSD', 'EWC'),
#   ('SLX', 'FXH'),
#   ('PXH', 'EWH'),
#   ('XME', 'IVV'),
#   ('ITOT', 'IYW'),
#   ('EEM', 'BJK'),
#   ('SCJ', 'FXH'),
#   ('EWC', 'IYC'),
#   ('PBE', 'MDYV'),
#   ('DFJ', 'PFI'),
#   ('JPXN', 'MGV'),
#   ('XLI', 'DVY'),
#   ('DFE', 'PXJ'),
#   ('CSM', 'IXN'),
#   ('PYZ', 'IYK'),
#   ('GRID', 'SCHB'),
#   ('IJR', 'XRT'),
#   ('DIA', 'AFK'),
#   ('FXZ', 'FTA'),
#   ('ACWX', 'EMIF'),
#   ('PSJ', 'FEX'),
#   ('SCJ', 'SCHB'),
#   ('AAXJ', 'NORW'),
#   ('UPW', 'FDL'),
#   ('XLK', 'IYC'),
#   ('VNM', 'CZA'),
#   ('RYU', 'PIE'),
#   ('XBI', 'EFO'),
#   ('VGT', 'RSP'),
#   ('XLK', 'DON'),
#   ('IGN', 'FEX'),
#   ('XLK', 'FXG'),
#   ('QTEC', 'IWP'),
#   ('XBI', 'MGV'),
#   ('VCR', 'IYT'),
#   ('XME', 'VTI'),
#   ('INDY', 'RYU'),
#   ('PRF', 'IYW'),
#   ('XLP', 'XLB'),
#   ('PSJ', 'IMCG'),
#   ('XNTK', 'FIW'),
#   ('KBE', 'IYG'),
#   ('FXZ', 'IYW'),
#   ('VBK', 'IJH'),
#   ('GRID', 'IYW'),
#   ('QQXT', 'DVY'),
#   ('IAK', 'IYW'),
#   ('PSJ', 'XLY'),
#   ('IHE', 'ILF'),
#   ('XBI', 'ACWX'),
#   ('GRID', 'UCC'),
#   ('FNX', 'VGT'),
#   ('SPEM', 'BJK'),
#   ('MGV', 'IWL'),
#   ('VPU', 'IDX'),
#   ('EWZ', 'XLP'),
#   ('NORW', 'PUI'),
#   ('PBE', 'DIA'),
#   ('XLI', 'VOE'),
#   ('EPS', 'QCLN'),
#   ('DHS', 'ILF'),
#   ('GRID', 'IWL'),
#   ('QQXT', 'FXZ'),
#   ('PWC', 'IGE'),
#   ('IXN', 'PHO'),
#   ('IHE', 'SPDW'),
#   ('IGN', 'IUSG'),
#   ('VPU', 'IXP'),
#   ('EMIF', 'IDV'),
#   ('IYY', 'IYW'),
#   ('ITA', 'RTH'),
#   ('IGN', 'UYM'),
#   ('DWM', 'GII'),
#   ('SPYV', 'CSM'),
#   ('SCJ', 'IWB'),
#   ('EWC', 'QTEC'),
#   ('IWY', 'FTCS'),
#   ('IHE', 'VEU'),
#   ('ERTH', 'ILCV'),
#   ('RYJ', 'SMH'),
#   ('SCJ', 'SSO'),
#   ('FXO', 'ROM'),
#   ('JPXN', 'TECL'),
#   ('ONEQ', 'SCHX'),
#   ('PSJ', 'XMHQ'),
#   ('FNI', 'EWH'),
#   ('XBI', 'DLS'),
#   ('EFA', 'EWO'),
#   ('JPXN', 'IWL'),
#   ('QCLN', 'DSI'),
#   ('KXI', 'VEU'),
#   ('DLS', 'TOK'),
#   ('RYF', 'RPV'),
#   ('XPP', 'PGJ'),
#   ('EWG', 'VPL'),
#   ('EES', 'FEX'),
#   ('VTV', 'IWL'),
#   ('ONEQ', 'FTA'),
#   ('VTV', 'EWJ'),
#   ('XPP', 'NORW'),
#   ('VNM', 'CGW'),
#   ('IGN', 'EWC'),
#   ('VDC', 'XPH'),
#   ('SPYV', 'ILCG'),
#   ('PRFZ', 'XRT'),
#   ('RFV', 'RTH'),
#   ('EFO', 'IGF'),
#   ('VNM', 'CVY'),
#   ('VGK', 'CHII'),
#   ('PSJ', 'EWC'),
#   ('PBD', 'VHT'),
#   ('EWC', 'FTA'),
#   ('SPEM', 'NORW'),
#   ('SCHF', 'DNL'),
#   ('XLI', 'PEJ'),
#   ('FXD', 'FYX'),
#   ('IGN', 'FPX'),
#   ('EWZ', 'IDHQ'),
#   ('ITA', 'DSI'),
#   ('PBE', 'DVY'),
#   ('IYF', 'PPA'),
#   ('EMIF', 'GWX'),
#   ('DTD', 'AFK'),
#   ('IGN', 'RGI'),
#   ('WOOD', 'PKW'),
#   ('ROM', 'SCHV'),
#   ('SLX', 'EQWL'),
#   ('RESP', 'XLK'),
#   ('XBI', 'IDHQ'),
#   ('VNM', 'UYM'),
#   ('SCHF', 'EWU'),
#   ('ADRE', 'BJK'),
#   ('GXC', 'IXP'),
#   ('CSM', 'SCJ'),
#   ('IWS', 'IYJ'),
#   ('IXN', 'SCHV'),
#   ('ISCV', 'IYW'),
#   ('AMJ', 'VOX'),
#   ('SCJ', 'PHO'),
#   ('FAD', 'RYT'),
#   ('SPTM', 'IYW'),
#   ('QQEW', 'IWR'),
#   ('QQQ', 'EWW'),
#   ('EXI', 'XLB'),
#   ('EWL', 'IHE'),
#   ('FTC', 'XRT'),
#   ('RPV', 'IXN'),
#   ('XLI', 'XRT'),
#   ('RFV', 'MIDU'),
#   ('IYK', 'AIA'),
#   ('KXI', 'BKF'),
#   ('IHE', 'DLS'),
#   ('EWZ', 'EWH'),
#   ('EWZ', 'PDN'),
#   ('WOOD', 'DDM'),
#   ('WOOD', 'DVY'),
#   ('IYK', 'UYM'),
#   ('EWS', 'DEF'),
#   ('IYJ', 'XRT'),
#   ('IYY', 'FXH'),
#   ('PEZ', 'IGM'),
#   ('WOOD', 'FXG'),
#   ('FYX', 'FXH'),
#   ('ITA', 'IXN'),
#   ('VNM', 'TOK'),
#   ('SCJ', 'SCHX'),
#   ('XNTK', 'FXH'),
#   ('PSI', 'SCJ'),
#   ('FIW', 'PTF'),
#   ('GRID', 'RXL'),
#   ('FXH', 'IYW'),
#   ('VT', 'EMIF'),
#   ('RESP', 'ILCG'),
#   ('AFK', 'FXG'),
#   ('DVY', 'IMCB'),
#   ('ROM', 'ILCB'),
#   ('VNM', 'NORW'),
#   ('PGJ', 'BKF'),
#   ('SCJ', 'IWS'),
#   ('EWZ', 'PIZ'),
#   ('SCJ', 'XMVM'),
#   ('XSD', 'PHO'),
#   ('CVY', 'BKF'),
#   ('EZA', 'DGS'),
#   ('PEZ', 'ISCB'),
#   ('PXH', 'EWD'),
#   ('WOOD', 'QQEW'),
#   ('XBI', 'EFA'),
#   ('SCHX', 'IYW'),
#   ('UPW', 'PIN'),
#   ('FXI', 'EWH'),
#   ('SCJ', 'VV'),
#   ('QLD', 'VOE'),
#   ('VNM', 'IXG'),
#   ('ONEQ', 'SPYV'),
#   ('ILCB', 'TECL'),
#   ('SCJ', 'PBS'),
#   ('VNM', 'CWI'),
#   ('ERTH', 'EQL'),
#   ('IJS', 'SLYV'),
#   ('EWZ', 'SPDW'),
#   ('SCJ', 'UPRO'),
#   ('ACWX', 'PSP'),
#   ('EMIF', 'CGW'),
#   ('XLU', 'CHII'),
#   ('IDU', 'CHII'),
#   ('SCJ', 'VOE'),
#   ('ILF', 'XPH'),
#   ('EWC', 'CZA'),
#   ('PEJ', 'XLY'),
#   ('FXD', 'IWS'),
#   ('VUG', 'XME'),
#   ('VNM', 'EMIF'),
#   ('AFK', 'VT'),
#   ('WOOD', 'CZA'),
#   ('ERTH', 'UGE'),
#   ('VPU', 'EWH'),
#   ('EZJ', 'SPXL'),
#   ('IYK', 'RTM'),
#   ('FIW', 'RWK'),
#   ('EES', 'IWS'),
#   ('AFK', 'CUT'),
#   ('FXZ', 'EZM'),
#   ('SPXL', 'IXN'),
#   ('RPV', 'ROM'),
#   ('VNM', 'EWK'),
#   ('DNL', 'ADRE'),
#   ('EWN', 'XBI'),
#   ('RPV', 'TECL'),
#   ('FXZ', 'MVV'),
#   ('IGN', 'RXI'),
#   ('FXL', 'EVX'),
#   ('ITA', 'IWX'),
#   ('XLI', 'EWC'),
#   ('DIM', 'DNL'),
#   ('IHE', 'EWY'),
#   ('ADRE', 'AIA'),
#   ('EXI', 'RTM'),
#   ('GRID', 'EWH'),
#   ('PBE', 'IYY'),
#   ('PRFZ', 'RCD'),
#   ('GRID', 'CWI'),
#   ('GWX', 'PJP'),
#   ('VNM', 'PID'),
#   ('VNM', 'PUI'),
#   ('EZJ', 'QCLN'),
#   ('FXZ', 'FXG'),
#   ('VNM', 'CUT'),
#   ('EWH', 'EWD'),
#   ('VNM', 'VEA'),
#   ('WOOD', 'VGT'),
#   ('PBE', 'MDYG'),
#   ('EWZ', 'VPL'),
#   ('FYX', 'XRT'),
#   ('XSVM', 'IXN'),
#   ('IAK', 'QCLN'),
#   ('PBE', 'SLX'),
#   ('ERTH', 'JPXN'),
#   ('RYJ', 'XSMO'),
#   ('DHS', 'EWD'),
#   ('GRES', 'PNQI'),
#   ('RYT', 'XLI'),
#   ('IGN', 'PYZ'),
#   ('FAD', 'PEJ'),
#   ('PSJ', 'FXZ'),
#   ('ADRE', 'CUT'),
#   ('PBE', 'MVV'),
#   ('XBI', 'CWI'),
#   ('DEM', 'PJP'),
#   ('ADRE', 'GRES'),
#   ('SCHG', 'IYW'),
#   ('XLP', 'IVW'),
#   ('XMVM', 'UCC'),
#   ('XPP', 'EWH'),
#   ('ROM', 'IUSV'),
#   ('PSJ', 'PDP'),
#   ('ITOT', 'SCJ'),
#   ('SCJ', 'IWL'),
#   ('ADRE', 'EWH'),
#   ('JPXN', 'SPXL'),
#   ('VPL', 'DNL'),
#   ('XBI', 'SSO'),
#   ('ADRE', 'CZA'),
#   ('VNM', 'EZU'),
#   ('FDD', 'GII'),
#   ('EWZ', 'EFG'),
#   ('EMIF', 'PJP'),
#   ('XNTK', 'VIG'),
#   ('DES', 'XMVM'),
#   ('DFJ', 'IJS'),
#   ('ONEQ', 'IWS'),
#   ('EWY', 'EVX'),
#   ('IGN', 'XME'),
#   ('IWV', 'VGT'),
#   ('IJR', 'PEZ'),
#   ('ISCV', 'XLK'),
#   ('ILF', 'PGJ'),
#   ('VPU', 'DEF'),
#   ('PDP', 'FEX'),
#   ('VNM', 'IDHQ'),
#   ('PRF', 'VGT'),
#   ('ISCV', 'SAA'),
#   ('XMMO', 'IGE'),
#   ('VNM', 'PKB'),
#   ('IVE', 'DFJ'),
#   ('IGN', 'IWF'),
#   ('SLX', 'TOK'),
#   ('XLK', 'UYM'),
#   ('PDN', 'EMIF'),
#   ('QQXT', 'XLP'),
#   ...]]

# %% [markdown]
# # -----------------------------------------------------------------

# %% [markdown]
# # 이하 Pair_selection 작동 로직 풀어서 보여주기

# %%
test_list = list(clustered_series[clustered_series == clusters_viz_list[0]].index)
test_list
# Out:
# ['SEF', 'SKF', 'FAZ']

# %% [markdown]
# ## 1. 거래량이 충분한 종목인지 - 10분위 이하는 제거

# %%
etf_info = pd.read_csv('/Users/yjban/Desktop/MFE/BAF646_Statistical_arbitrage/project/data/etf_list/etfs_details_equity.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /Users/Sun/Documents/Github/Statistical-Arbitrage/Final/pair_selection_DBSCAN.ipynb 셀 32 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/Sun/Documents/Github/Statistical-Arbitrage/Final/pair_selection_DBSCAN.ipynb#X44sZmlsZQ%3D%3D?line=0'>1</a> etf_info = pd.read_csv('/Users/yjban/Desktop/MFE/BAF646_Statistical_arbitrage/project/data/etf_list/etfs_details_equity.csv')
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/quant/lib/python3.8/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/quant/lib/python3.8/site-packages/pandas/io/parsers/readers.py:680, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     665 kwds_defaults = _refine_defaults_read(
#     666     dialect,
#     667     delimiter,
#    (...)
#     676     defaults={"delimiter": ","},
#     677 )
#     678 kwds.update(kwds_defaults)
# --> 680 return _read(filepath_or_buffer, kwds)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/quant/lib/python3.8/site-packages/pandas/io/parsers/readers.py:575, in _read(filepath_or_buffer, kwds)
#     572 _validate_names(kwds.get("names", None))
#     574 # Create the parser.
# --> 575 parser = TextFileReader(filepath_or_buffer, **kwds)
#     577 if chunksize or iterator:
#     578     return parser
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/quant/lib/python3.8/site-packages/pandas/io/parsers/readers.py:934, in TextFileReader.__init__(self, f, engine, **kwds)
#     931     self.options["has_index_names"] = kwds["has_index_names"]
#     933 self.handles: IOHandles | None = None
# --> 934 self._engine = self._make_engine(f, self.engine)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/quant/lib/python3.8/site-packages/pandas/io/parsers/readers.py:1218, in TextFileReader._make_engine(self, f, engine)
#    1214     mode = "rb"
#    1215 # error: No overload variant of "get_handle" matches argument types
#    1216 # "Union[str, PathLike[str], ReadCsvBuffer[bytes], ReadCsvBuffer[str]]"
#    1217 # , "str", "bool", "Any", "Any", "Any", "Any", "Any"
# -> 1218 self.handles = get_handle(  # type: ignore[call-overload]
#    1219     f,
#    1220     mode,
#    1221     encoding=self.options.get("encoding", None),
#    1222     compression=self.options.get("compression", None),
#    1223     memory_map=self.options.get("memory_map", False),
#    1224     is_text=is_text,
#    1225     errors=self.options.get("encoding_errors", "strict"),
#    1226     storage_options=self.options.get("storage_options", None),
#    1227 )
#    1228 assert self.handles is not None
#    1229 f = self.handles.handle
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/quant/lib/python3.8/site-packages/pandas/io/common.py:786, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     781 elif isinstance(handle, str):
#     782     # Check whether the filename is to be opened in binary mode.
#     783     # Binary mode does not support 'encoding' and 'newline'.
#     784     if ioargs.encoding and "b" not in ioargs.mode:
#     785         # Encoding
# --> 786         handle = open(
#     787             handle,
#     788             ioargs.mode,
#     789             encoding=ioargs.encoding,
#     790             errors=errors,
#     791             newline="",
#     792         )
#     793     else:
#     794         # Binary mode
#     795         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/yjban/Desktop/MFE/BAF646_Statistical_arbitrage/project/data/etf_list/etfs_details_equity.csv'

# %%
etf_info['volume'] = etf_info['Avg. Daily Volume'].str.replace(',','').astype('float')

# %%
low_volume_etf = etf_info[etf_info.volume < etf_info.volume.quantile(0.1)].Symbol.to_list()

# %%
vol_screened_test_list = []
for x in test_list:
    if (x in low_volume_etf) == False:
        vol_screened_test_list.append(x)

# %%
vol_screened_test_list
# Out:
# ['SEF', 'SKF', 'FAZ']

# %% [markdown]
# ## 2. corr -0.99 이상인 etf가 존재하는지 -> 숏포지션 잡을 수 있는지 여부

# %%
etf_info[etf_info.Symbol.apply(lambda x : x in test_list )]
# Out:
#      Symbol                                 ETF Name Asset Class  \
# 821     FAZ  Direxion Daily Financial Bear 3X Shares      Equity
# 1354    SEF               ProShares Short Financials      Equity
# 1577    SKF          ProShares UltraShort Financials      Equity
#
#      Total Assets  YTD Price Change Avg. Daily Volume Previous Closing Price  \
# 821   $193,456,000           -4.77%         3,835,680                 $18.15
# 1354   $33,894,100            9.27%            98,253                 $12.73
# 1577   $16,655,100           13.54%            63,388                 $18.78
#
#      1-Day Change Inverse Leveraged  ... Volatility Rating Dividend Rating  \
# 821         1.51%     Yes       -3x  ...                 B               A
# 1354        0.63%     Yes       -1x  ...                A-               B
# 1577        1.40%     Yes       -2x  ...                A-              B-
#
#      Concentration Rating ESG Score ESG Score Peer Percentile (%)  \
# 821                     B      5.67                        18.64%
# 1354                   A-      0.00                           NaN
# 1577                   B-      0.00                           NaN
#
#      ESG Score Global Percentile (%)  \
# 821                           30.27%
# 1354                             NaN
# 1577                             NaN
#
#      Carbon Intensity (Tons of CO2e / $M Sales) SRI Exclusion Criteria (%)  \
# 821                                         1.5                      0.00%
# 1354                                        NaN                        NaN
# 1577                                        NaN                        NaN
#
#      Sustainable Impact Solutions (%)     volume
# 821                             0.00%  3835680.0
# 1354                              NaN    98253.0
# 1577                              NaN    63388.0
#
# [3 rows x 54 columns]

# %%
short_avail_test_list = []
for x in vol_screened_test_list:
    print(rtn_df.corr()[x].idxmin(), rtn_df.corr()[x].min())

    if rtn_df.corr()[x].min() < -0.99:
        short_avail_test_list.append(x)
        
short_avail_test_list
# Out:
# UYG -0.9982213566272626
# UYG -0.9988644649314099
# FAS -0.9994180633078865
# ['SEF', 'SKF', 'FAZ']

# %% [markdown]
# ## 3. Cointegration - pvalue 0.05 이하인 pair sorting

# %%
log_price_data = np.log(close_df[short_avail_test_list])
comb = list(combinations(short_avail_test_list, 2))
eg_pvalue = {}

for x in comb:
    score, pvalue, _ = coint(log_price_data[x[0]], log_price_data[x[1]], method='aeg')
    eg_pvalue[x] = pvalue

print(eg_pvalue)
print('------------------------------------------------')
print('best pair: ', min(eg_pvalue, key=eg_pvalue.get))
# Out:
# {('SEF', 'SKF'): 0.7733920785648577, ('SEF', 'FAZ'): 0.6377026867361617, ('SKF', 'FAZ'): 0.5578237045095392}
# ------------------------------------------------
# best pair:  ('SKF', 'FAZ')

# %%
possible_pair = [x[0] for x in sorted(eg_pvalue.items(), key=lambda item: item[1]) if x[1] <= 0.05]

# %%
possible_pair
# Out:
# []

# %% [markdown]
# ## 4. Hurst exponent test - mean reverting intensity : H < 0.5 이하인 종목 선정

# %%
spread_df = pd.DataFrame(index = log_price_data.index)

for x in possible_pair:
    spread_df[x] = close_df[x[0]] - close_df[x[1]]

# %%
hurst_screened_list = []

for cnd in possible_pair:
    if compute_Hc(spread_df[cnd])[0] <= 0.5:
        hurst_screened_list.append(cnd)

# %%
hurst_screened_list
# Out:
# [('SKF', 'FAZ'), ('SEF', 'FAZ'), ('SEF', 'SKF')]

# %%
spread_df = spread_df[hurst_screened_list]

# %% [markdown]
# ## 5. Half life가 trading period 안에 들어오는 종목 스크리닝

# %%
spread_df_lag = spread_df.shift(1)
spread_df_diff = spread_df - spread_df_lag

hl_screened_list = []
for i in range(len(hurst_screened_list)):
    X = sm.add_constant(spread_df_lag.iloc[1:,i])
    model = sm.OLS(spread_df_diff.iloc[1:,i], X)
    result = model.fit()
    lamda = result.params[1]
    HL = -np.log(2) / lamda

# trading period 고려
    if (HL <= 30) & (HL >= 1):
        hl_screened_list.append(hurst_screened_list[i])

# %%
hl_screened_list
# Out:
# [('SKF', 'FAZ'), ('SEF', 'FAZ'), ('SEF', 'SKF')]

# %%
spread_df = spread_df[hl_screened_list]

# %% [markdown]
# ## 6. mean-reverting freq이 충분히 자주 발생하는지 스크리닝

# %%
freq_screened_list = []

for j in range(len(spread_df.columns)):

    cnt = 0

    for i in range(len(spread_df.index)):

        if i == len(spread_df.index) -1:
            break

        elif spread_df.iloc[i+1,j] >= spread_df.iloc[i,j]:
            if (spread_df.mean()[j] >= spread_df.iloc[i,j]) & (spread_df.mean()[j] <= spread_df.iloc[i+1,j]):
                cnt += 1

        else:
            if (spread_df.mean()[j] >= spread_df.iloc[i+1,j]) & (spread_df.mean()[j] <= spread_df.iloc[i,j]):
                cnt += 1
    
    if cnt >= 12:
        freq_screened_list.append(hl_screened_list[j])

# %%
freq_screened_list
# Out:
# [('SKF', 'FAZ'), ('SEF', 'FAZ'), ('SEF', 'SKF')]

# %%
100 * (1.03 * 6.38 + 100) / (103 - 6.38 * 1.03)
# Out:
# 110.51845614267965
